# %%
    import pandas as pd
    import numpy as np
    import sklearn
    import nltk
    # %matplotlib inline

# %%
df_vader = pd.read_csv("labelled_tweets_vader_final.csv")
df_vader.head(10)
# Out:
#    Unnamed: 0 created_at            id  \
# 0           0     Mar-05  1.370000e+18
# 1           1     Mar-05  1.370000e+18
# 2           2     Mar-05  1.370000e+18
# 3           3     Mar-05  1.370000e+18
# 4           4     Mar-05  1.370000e+18
# 5           5     Mar-05  1.370000e+18
# 6           6     Mar-05  1.370000e+18
# 7           7     Mar-05  1.370000e+18
# 8           8     Mar-05  1.370000e+18
# 9           9     Mar-05  1.370000e+18
#
#                                            full_text  \
# 0  no fact-checker can beat the speed of my dad b...
# 1      more than 1.90 cr vaccine doses administered.
# 2  the data indicates that the astrazeneca covid ...
# 3  with 81% efficacy in the interim findings, has...
# 4  the thursday asked centre to explain the ratio...
# 5  the best covid19 medicine is the one available...
# 6  covaxin vaccine : 81% efficacy pm modi took th...
# 7  india is partly free =========================...
# ...

# %%
df_textblob = pd.read_csv("labelled_tweets_textblob.csv")

# %%
df_vader = df_vader.assign(sentiments_textblob = df_textblob['sentiments_textblob'].values)
df_vader.head()
# Out:
#    Unnamed: 0 created_at            id  \
# 0           0     Mar-05  1.370000e+18
# 1           1     Mar-05  1.370000e+18
# 2           2     Mar-05  1.370000e+18
# 3           3     Mar-05  1.370000e+18
# 4           4     Mar-05  1.370000e+18
#
#                                            full_text  \
# 0  no fact-checker can beat the speed of my dad b...
# 1      more than 1.90 cr vaccine doses administered.
# 2  the data indicates that the astrazeneca covid ...
# 3  with 81% efficacy in the interim findings, has...
# 4  the thursday asked centre to explain the ratio...
#
#                                               source  retweet_count  \
# 0  <a href="http://twitter.com/download/android" ...            131
# 1  <a href="https://mobile.twitter.com" rel="nofo...              0
# 2  <a href="https://about.twitter.com/products/tw...              4
# 3  <a href="https://about.twitter.com/products/tw...              4
# ...

# %%
df_vader.to_csv("labelled_tweets_compiled.csv")
